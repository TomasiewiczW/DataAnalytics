# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#1
Data = pd.read_csv('Data1.csv')

# %%
Data
# Out:
#       Unnamed: 0   theta_1   theta_2   theta_3   theta_4   theta_5    theta_6
# 0     2017-01-01  0.756936 -1.467790  0.096136 -0.115306 -0.447908   0.902579
# 1     2017-01-02  0.767089  0.185797 -1.428536 -0.086443 -0.954288   1.930909
# 2     2017-01-03  0.404544  1.415887  0.443466  0.000200 -0.892351   2.449691
# 3     2017-01-04  1.313957 -1.804471 -0.836986  0.011785 -1.012518   1.182085
# 4     2017-01-05  0.209862  1.315868  0.140993 -0.046473 -1.417092   1.742433
# ...          ...       ...       ...       ...       ...       ...        ...
# 1090  2019-12-27 -1.520171 -1.128868  1.108275  0.936817  0.948045  11.755980
# 1091  2019-12-28  0.338910 -3.178251  1.484579  1.051123  1.025288  11.397092
# 1092  2019-12-29  0.263781  0.045725 -0.112476  0.823782  0.914111  10.918941
# 1093  2019-12-30 -0.425098 -1.002701 -0.834294  0.850904  0.801977  11.140722
# 1094  2019-12-31  0.848302  3.510521 -0.280626  0.967050  1.091803  11.989975
#
# [1095 rows x 7 columns]

# %% [markdown]
# - The table above has 1095 rows and 6 columns of random numbers

# %%
#2
Data=Data.set_index(Data.columns[0])
Data
# Out:
#              theta_1   theta_2   theta_3   theta_4   theta_5    theta_6
# Unnamed: 0
# 2017-01-01  0.756936 -1.467790  0.096136 -0.115306 -0.447908   0.902579
# 2017-01-02  0.767089  0.185797 -1.428536 -0.086443 -0.954288   1.930909
# 2017-01-03  0.404544  1.415887  0.443466  0.000200 -0.892351   2.449691
# 2017-01-04  1.313957 -1.804471 -0.836986  0.011785 -1.012518   1.182085
# 2017-01-05  0.209862  1.315868  0.140993 -0.046473 -1.417092   1.742433
# ...              ...       ...       ...       ...       ...        ...
# 2019-12-27 -1.520171 -1.128868  1.108275  0.936817  0.948045  11.755980
# 2019-12-28  0.338910 -3.178251  1.484579  1.051123  1.025288  11.397092
# 2019-12-29  0.263781  0.045725 -0.112476  0.823782  0.914111  10.918941
# 2019-12-30 -0.425098 -1.002701 -0.834294  0.850904  0.801977  11.140722
# 2019-12-31  0.848302  3.510521 -0.280626  0.967050  1.091803  11.989975
#
# [1095 rows x 6 columns]

# %% [markdown]
# - First column set as index, so data can be found by the date

# %%
#3
cols=['theta_1','theta_2','theta_3','theta_4','theta_5','theta_6']
Data[cols].plot(subplots=True,figsize=(15,10))
plt.show()

# %% [markdown]
# - Data is presented on the 6 grids with the same date

# %%
# 4
Data2=Data.melt()
Data2
# Out:
#      variable      value
# 0     theta_1   0.756936
# 1     theta_1   0.767089
# 2     theta_1   0.404544
# 3     theta_1   1.313957
# 4     theta_1   0.209862
# ...       ...        ...
# 6565  theta_6  11.755980
# 6566  theta_6  11.397092
# 6567  theta_6  10.918941
# 6568  theta_6  11.140722
# 6569  theta_6  11.989975
#
# [6570 rows x 2 columns]

# %% [markdown]
# - Melting the data reshapes it to distinghised variables in columns and assigns the value listed for each of them. It removes dataIndex.

# %%
Graph=sns.FacetGrid(Data2, col="variable", sharex=False, col_wrap=3)
Graph.map(plt.hist,"value")

# %% [markdown]
# - Melting allows to map the values for each variable and create histograms. If one rescales them, they can present probability of occurance.

# %%
#5
for i in cols:
    plt.figure()
    sns.distplot(Data[i], kde=True, hist=False)

# %%
#6
Data2018 = Data['2018-01-01':'2019-01-01']

cols2018 = Data.columns
cols2018 = cols2018[0:4]
print(cols2018)
Reduced2018 = Data2018[cols2018]

Melted2018 = Reduced2018.melt()

Reduced2018.plot(subplots=True,figsize=(15,10))
plt.show()
# Out:
# Index(['theta_1', 'theta_2', 'theta_3', 'theta_4'], dtype='object')

# %% [markdown]
# - Subsetting data from one year

# %%
plt.figure()
grid = sns.FacetGrid(Melted2018, col="variable")
grid.map(plt.hist, "value")

# %% [markdown]
# - sns allows to trim the data eg. one year 2018

# %%
for i in cols2018:
    plt.figure()
    sns.distplot(Reduced2018[i], kde=True, hist=False)

# %% [markdown]
# - The density of the model. Allows to operate on the model with powerful probabilistic tools.
